# %%
#Load packages
import sys

import requests
import re
import string
import time
import datetime

import pandas as pd

from lxml import html
from lxml import etree

import numpy as np

# %%
def flatten(l):
    return np.concatenate(l)

# %%
#Load data collected at Booth
info_2015 = pd.read_csv("../training_data/Info_2015.csv", delimiter="\t")
info_2022 = pd.read_csv("../training_data/Info_2022.csv", delimiter="\t")

#Create a dataframe for webpage links for which we need to extract nodes and xpaths

links=[]
links.append(list(set(info_2015['snapshot_link'])))
links.append(list(set(info_2022['snapshot_link'])))

links = flatten(links)

for link in links:
    print(link)
# Out:
# https://web.archive.org/web/20150217144133/https://www.apartments.com/chicago-il/
# https://web.archive.org/web/20220612023135/https://www.apartments.com/chicago-il/
# https://web.archive.org/web/20220321160908/https://www.apartments.com/chicago-il/
# https://web.archive.org/web/20220121035604/https://www.apartments.com/chicago-il/
# https://web.archive.org/web/20220426234339/https://www.apartments.com/chicago-il/
# https://web.archive.org/web/20220403132436/https://www.apartments.com/chicago-il/

# %%
# print("Start Time", start_requests)

for i, link in enumerate(links):
    print(i, str(link))
    start_requests = datetime.datetime.now()    
    try:
        response = requests.get(str(link), proxies={'http': '222.255.169.74:8080'}, timeout=5)
#         print(response.status_code)
    except requests.exceptions.Timeout:
        print('The request timed out')

    root = html.fromstring(response.text)
    tree = root.getroottree()

    parents_blacklist=['[document]','html','head',
                       'style','script','body',
                       'section','tr',
                       'td','label','ul','header',
                       'aside']

    regexpNS = "http://exslt.org/regular-expressions"
    finds = root.xpath("//*[re:test(., '[a-zA-Z0-9]', 'i')]", namespaces={'re':regexpNS})

    total_nodes = 1
    nodes = []
    xpaths = []

    start = datetime.datetime.now()

    for i, find in enumerate(finds):
        path = tree.getpath(find)
        if i == len(finds) - 1:
            text = tree.xpath(path)[0].text
            if text != None and len(text) > 0 and len(text) < 60 and text != " ":
                total_nodes = total_nodes + 1
                nodes.append(text.strip())
                xpaths.append(path)
                break
        else:
            path_next = tree.getpath(finds[i+1])         
            if path in path_next:
                continue
            else:
                text = tree.xpath(path)[0].text
                if text != None and len(text) > 0 and len(text) < 60 and text != " ":
    #                 print(text.strip(), path)
                    total_nodes = total_nodes + 1
                    nodes.append(text.strip())
                    xpaths.append(str(path))

    # print("\n \n Total Number of Nodes Are:", total_nodes) 
    # print(nodes)
    # print(xpaths)
    dataset = pd.DataFrame({"nodes": nodes, "xpaths":xpaths})

    print(dataset)

    # dataset.to_csv("nodes_xpaths_test.csv", sep='\t')
# Out:
# Start Time 2023-03-29 16:20:36.395339
# 0 https://web.archive.org/web/20150217144133/https://www.apartments.com/chicago-il/
# Requests Time Elapsed 0:00:00.370103
#                                                  nodes  \
# 0    Apartments for Rent in Chicago, IL | Apartment...
# 1                                                 Menu
# 2                                              Sign In
# 3                                        Add a Listing
# 4                                       Back To Search
# ..                                                 ...
# 592                                       We're Sorry!
# 593                                                 Ok
# 594                                       We're Sorry!
# 595  Your location was not found. Please try again ...
# 596                                                 Ok
#
#                                                 xpaths
# 0                                     /html/head/title
# 1    /html/body/div[1]/header/nav/div[1]/span/butto...
# 2             /html/body/div[1]/header/nav/div[2]/a[1]
# 3             /html/body/div[1]/header/nav/div[2]/a[2]
# 4         /html/body/div[1]/main/section/header/a/span
# ..                                                 ...
# 592   /html/body/div[1]/main/section/div[5]/div/div/h3
# 593  /html/body/div[1]/main/section/div[5]/div/div/...
# 594   /html/body/div[1]/main/section/div[6]/div/div/h3
# 595    /html/body/div[1]/main/section/div[6]/div/div/p
# 596  /html/body/div[1]/main/section/div[6]/div/div/...
#
# [597 rows x 2 columns]
# 1 https://web.archive.org/web/20220612023135/https://www.apartments.com/chicago-il/
# Requests Time Elapsed 0:00:00.427330
#                                                   nodes  \
# 0     Apartments for Rent in Chicago IL | Apartments...
# 1                      bazadebezolkohpepadr="560702792"
# 2                                                  Menu
# 3                                          Renter Tools
# 4                                             Favorites
# ...                                                 ...
# 1278               Thank you! Your email has been sent.
# 1279                                    Ready to Apply?
# 1280                                   Sign Up to Apply
# 1281                                            sign in
# 1282                         window.cohortVariant = -1;
#
#                                                  xpaths
# 0                                      /html/head/title
# 1                                  /html/head/script[5]
# 2       /html/body/div[1]/header/nav/div[1]/button/span
# 3     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 4     /html/body/div[1]/header/nav/div[1]/div/div/di...
# ...                                                 ...
# 1278  /html/body/div[1]/main/section/div[2]/div[3]/d...
# 1279  /html/body/div[1]/main/section/div[3]/div/div/...
# 1280  /html/body/div[1]/main/section/div[3]/div/div/...
# 1281  /html/body/div[1]/main/section/div[3]/div/div/...
# 1282                               /html/body/script[1]
#
# [1283 rows x 2 columns]
# 2 https://web.archive.org/web/20220321160908/https://www.apartments.com/chicago-il/
# Requests Time Elapsed 0:00:00.424532
#                                                   nodes  \
# 0     Apartments for Rent in Chicago IL | Apartments...
# 1                                                  Menu
# 2                                          Renter Tools
# 3                                             Favorites
# 4                                        Saved Searches
# ...                                                 ...
# 1153               Thank you! Your email has been sent.
# 1154                                    Ready to Apply?
# 1155                                   Sign Up to Apply
# 1156                                            sign in
# 1157                         window.cohortVariant = -1;
#
#                                                  xpaths
# 0                                      /html/head/title
# 1       /html/body/div[1]/header/nav/div[1]/button/span
# 2     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 3     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 4     /html/body/div[1]/header/nav/div[1]/div/div/di...
# ...                                                 ...
# 1153  /html/body/div[1]/main/section/div[2]/div[3]/d...
# 1154  /html/body/div[1]/main/section/div[3]/div/div/...
# 1155  /html/body/div[1]/main/section/div[3]/div/div/...
# 1156  /html/body/div[1]/main/section/div[3]/div/div/...
# 1157                               /html/body/script[1]
#
# [1158 rows x 2 columns]
# 3 https://web.archive.org/web/20220121035604/https://www.apartments.com/chicago-il/
# Requests Time Elapsed 0:00:00.436658
#                                                   nodes  \
# 0     Apartments for Rent in Chicago IL | Apartments...
# 1                                                  Menu
# 2                                          Renter Tools
# 3                                             Favorites
# 4                                        Saved Searches
# ...                                                 ...
# 1164               Thank you! Your email has been sent.
# 1165                                    Ready to Apply?
# 1166                                   Sign Up to Apply
# 1167                                            sign in
# 1168                         window.cohortVariant = -1;
#
#                                                  xpaths
# 0                                      /html/head/title
# 1       /html/body/div[1]/header/nav/div[1]/button/span
# 2     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 3     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 4     /html/body/div[1]/header/nav/div[1]/div/div/di...
# ...                                                 ...
# 1164  /html/body/div[1]/main/section/div[2]/div[3]/d...
# 1165  /html/body/div[1]/main/section/div[3]/div/div/...
# 1166  /html/body/div[1]/main/section/div[3]/div/div/...
# 1167  /html/body/div[1]/main/section/div[3]/div/div/...
# 1168                               /html/body/script[1]
#
# [1169 rows x 2 columns]
# 4 https://web.archive.org/web/20220426234339/https://www.apartments.com/chicago-il/
# Requests Time Elapsed 0:00:00.464559
#                                                   nodes  \
# 0     Apartments for Rent in Chicago IL | Apartments...
# 1                      bazadebezolkohpepadr="560701554"
# 2                                                  Menu
# 3                                          Renter Tools
# 4                                             Favorites
# ...                                                 ...
# 1154               Thank you! Your email has been sent.
# 1155                                    Ready to Apply?
# 1156                                   Sign Up to Apply
# 1157                                            sign in
# 1158                         window.cohortVariant = -1;
#
#                                                  xpaths
# 0                                      /html/head/title
# 1                                  /html/head/script[5]
# 2       /html/body/div[1]/header/nav/div[1]/button/span
# 3     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 4     /html/body/div[1]/header/nav/div[1]/div/div/di...
# ...                                                 ...
# 1154  /html/body/div[1]/main/section/div[2]/div[3]/d...
# 1155  /html/body/div[1]/main/section/div[3]/div/div/...
# 1156  /html/body/div[1]/main/section/div[3]/div/div/...
# 1157  /html/body/div[1]/main/section/div[3]/div/div/...
# 1158                               /html/body/script[1]
#
# [1159 rows x 2 columns]
# 5 https://web.archive.org/web/20220403132436/https://www.apartments.com/chicago-il/
# Requests Time Elapsed 0:00:00.439319
#                                                   nodes  \
# 0     Apartments for Rent in Chicago IL | Apartments...
# 1                      bazadebezolkohpepadr="560701588"
# 2                                                  Menu
# 3                                          Renter Tools
# 4                                             Favorites
# ...                                                 ...
# 1180               Thank you! Your email has been sent.
# 1181                                    Ready to Apply?
# 1182                                   Sign Up to Apply
# 1183                                            sign in
# 1184                         window.cohortVariant = -1;
#
#                                                  xpaths
# 0                                      /html/head/title
# 1                                  /html/head/script[5]
# 2       /html/body/div[1]/header/nav/div[1]/button/span
# 3     /html/body/div[1]/header/nav/div[1]/div/div/di...
# 4     /html/body/div[1]/header/nav/div[1]/div/div/di...
# ...                                                 ...
# 1180  /html/body/div[1]/main/section/div[2]/div[3]/d...
# 1181  /html/body/div[1]/main/section/div[3]/div/div/...
# 1182  /html/body/div[1]/main/section/div[3]/div/div/...
# 1183  /html/body/div[1]/main/section/div[3]/div/div/...
# 1184                               /html/body/script[1]
#
# [1185 rows x 2 columns]
