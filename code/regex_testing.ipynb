# %%
import requests
import time
import os
import pandas as pd
import numpy as np
import random
import re
import regex
from time import sleep
from os import path
from pandas import DataFrame
from bs4 import BeautifulSoup
from random import randint

# %%
def get_contents(soup, content_text):
  try:
    parents_blacklist=['[document]','html','head',
                       'style','script','body',
                       'section','tr',
                       'td','label','ul','header',
                       'aside']
    content=''
    text=soup.find_all(text=True)

    
    for t in text:
        if t.parent.name not in parents_blacklist and len(t) > 5:
            content=content+t+' '
    content_text.append(content)
  except Exception:
    content_text.append('')
    pass

# %%
def get_regex_data(webpage):
    page=requests.get(webpage)
    soup=BeautifulSoup(page.text,'html.parser')
    content_text = []
    get_contents(soup, content_text)
#     print(content_text[0])
    contacts = re.findall(r'\(?[0-9]{3}\)?\/?\.?-?\s?[0-9]{3}-?\.?-?\s?[0-9]{4}', content_text[0])
    address = regex.findall(r'[\s\n]*[1-9][0-9]{,4} (?:[A-Z][a-zA-Z]*,?\s*){,5} Chicago,?[\w\s,]{,3}\s*[0-9]{,6}?', content_text[0])
    address = [addi.strip() for addi in address]
    bed_range = re.findall(r'Studio\s*-\s*[1-9]\s*[a-zA-Z]+|[1-9]\s*-\s*[1-9]\s*[a-zA-Z]+|\s*Studio$|\s*[1-9]\s*[a-zA-Z]+,', content_text[0])
    prices = []
    prices = re.findall(r'\$[1-9]?[0-9]{,3},?[0-9]{,3}\s*-\s*\$?[1-9]?[0-9]{,3},?[0-9]{,3}', content_text[0])
    prices = re.findall(r'\$[1-9]?[0-9]{,3},?[0-9]{,3}\s*-\s*\$?[1-9]?[0-9]{,3},?[0-9]{,3}|\$[1-9]?[0-9]{,3},?[0-9]{,3}$|Call for Rent', content_text[0])
    print("\nContacts are:", contacts)
    print("\nAddresses are:", address)
    print("\nPrices are:" , prices)
    print("\nBeds are:" , bed_range)
    print("\nLengths of Filtered Lists are", len(contacts), len(address), len(prices), len(bed_range))

# %%
link = "https://web.archive.org/web/20160301213254/https://www.apartments.com/chicago-il/2/"

print("\nFor test link")
get_regex_data(link)
# Out:
# For test link
#
# Contacts are: ['312-462-0403', '844-737-7559', '312-219-9516', '844-250-5735', '844-741-2982', '844-837-3913', '844-294-8524', '844-406-5855', '844-841-6325', '844-368-4250', '844-525-6919', '844-811-0188', '773-675-1758', '312-646-4953', '866-661-2651', '773-570-3150', '877-331-6062', '708-546-4173', '312-789-5353', '844-233-2845', '888-449-2602', '888-380-0393', '773-358-4744', '877-834-2986', '773-649-4066']
#
# Addresses are: ['1350 N Lake Shore Dr Chicago', '1212 W Madison St Chicago', '1 W Superior St Chicago', '37 W Van Buren St Chicago', '910 W Huron St Chicago', '707 N Wells St Chicago', '730 W Couch Pl Chicago', '1225 N Wells St Chicago', '365 N Halsted St Chicago', '625 W Division St Chicago', '343 W Wolf Point Plz Chicago', '14 W Elm St Chicago', '355 E Ohio St Chicago', '180 N Jefferson St Chicago', '448 E Ontario St Chicago', '188 W Randolph St Chicago', '111 W Wacker Dr Chicago', '150 W Roosevelt Rd Chicago', '73 E Lake St Chicago', '215 E Chestnut St Chicago', '420 E Ohio St Chicago', '922 W Washington Blvd Chicago  C', '900 S Clark St Chicago', '2555 N Clark St Chicago']
#
# Prices are: ['$1,272 - $2,994', '$1,875 - $3,250', '$1,636 - $4,673', '$1,925 - $3,410', '$2,740 - $5,621', '$1,750 - $5,250', '$1,105 - $2,530', '$1,645 - $4,147', '$1,687 - $6,683', '$1,775 - $3,700', '$1,741 - $10,617', '$1,883 - $7,000', '$1,600 - $4,120', '$1,450 - $4,015', '$1,500 - $5,620', '$1,697 - $9,033', '$1,935 - $3,534', '$2,130 - $3,585', '$1,625 - $2,980', '$1,585 - $4,065', 'Call for Rent', '$1,711 - $3,351', '$1,493 - $2,228']
#
# Beds are: ['Studio - 2 Br', 'Studio - 2 Br', 'Studio - 2 Br', 'Studio - 4 Br', 'Studio - 4 Br', '1-3 Br', 'Studio - 3 Br', 'Studio - 3 Br', 'Studio - 3 Br', 'Studio - 3 Br', 'Studio - 2 Br', 'Studio - 3 Br', 'Studio - 3 Br', 'Studio - 3 Br', 'Studio - 2 Br', 'Studio - 2 Br', 'Studio - 3 Br', '1-2 Br', 'Studio - 2 Br', '1-2 Br', 'Studio - 3 Br', '1-3 Br', 'Studio - 2 Br']
#
# Lengths of Filtered Lists are 25 24 23 23

# %%
def get_regex_data_primary(webpage):
    page=requests.get(webpage)
    soup=BeautifulSoup(page.text,'html.parser')
    content_text = []
    get_contents(soup, content_text)
    contacts = r'\(?[0-9]{3}\)?\/?\.?-?\s?[0-9]{3}-?\.?-?\s?[0-9]{4}'
    address = r'[\s\n]*[1-9][0-9]{,4} (?:[A-Z][a-zA-Z]*,?\s*){,5} Chicago,?[\w\s,]{,3}\s*[0-9]{,6}?'
#     address = [addi.strip() for addi in address]
    bed_range = r'Studio\s*-\s*[1-9]\s*[a-zA-Z]+|[1-9]\s*-\s*[1-9]\s*[a-zA-Z]+|\s*Studio$|\s*[1-9]\s*[a-zA-Z]+,'
    prices = r'\$[1-9]?[0-9]{,3},?[0-9]{,3}\s*-\s*\$?[1-9]?[0-9]{,3},?[0-9]{,3}|\$[1-9]?[0-9]{,3},?[0-9]{,3}$|Call for Rent'
    total = r'\(?[0-9]{3}\)?\/?\.?-?\s?[0-9]{3}-?\.?-?\s?[0-9]{4}|[\s\n]*[1-9][0-9]{,4} (?:[A-Z][a-zA-Z]*,?\s*){,5} Chicago,?[\w\s,]{,3}\s*[0-9]{,6}?|Studio\s*-\s*[1-9]\s*[a-zA-Z]+|[1-9]\s*-\s*[1-9]\s*[a-zA-Z]+|\s*Studio$|\s*[1-9]\s*[a-zA-Z]+,|\$[1-9]?[0-9]{,3},?[0-9]{,3}\s*-\s*\$?[1-9]?[0-9]{,3},?[0-9]{,3}|\$[1-9]?[0-9]{,3},?[0-9]{,3}$|Call for Rent'
    output = re.findall(total,content_text[0])
    output = [out.strip() for out in output]
    return output

# %%
def consolidate(output):
    label_list = [{}]
    contacts = r'\(?[0-9]{3}\)?\/?\.?-?\s?[0-9]{3}-?\.?-?\s?[0-9]{4}'
    address = r'[\s\n]*[1-9][0-9]{,4} (?:[A-Z][a-zA-Z]*,?\s*){,5} Chicago,?[\w\s,]{,3}\s*[0-9]{,6}?'
    bed_range = r'Studio\s*-\s*[1-9]\s*[a-zA-Z]+|[1-9]\s*-\s*[1-9]\s*[a-zA-Z]+|\s*Studio$|\s*[1-9]\s*[a-zA-Z]+,'
    prices = r'\$[1-9]?[0-9]{,3},?[0-9]{,3}\s*-\s*\$?[1-9]?[0-9]{,3},?[0-9]{,3}|\$[1-9]?[0-9]{,3},?[0-9]{,3}$|Call for Rent'
    output_final = []
    property_info = {'Address': None, 'Price': None, 'Beds': None, 'Contact' : None}
    for i, out in enumerate(output):
        if re.match(address, out):
            if property_info['Address'] != None:
                output_final.append(property_info)
                property_info = {'Address': None, 'Price': None, 'Beds': None, 'Contact' : None}
                property_info['Address'] = out
            else:
                property_info['Address'] = out
        elif re.match(prices, out):
            if property_info['Price'] != None:
                output_final.append(property_info)
                property_info = {'Address': None, 'Price': None, 'Beds': None, 'Contact' : None}
                property_info['Price'] = out
            else:
                property_info['Price'] = out
        elif re.match(bed_range,out):
            if property_info['Beds'] != None:
                output_final.append(property_info)
                property_info = {'Address': None, 'Price': None, 'Beds': None, 'Contact' : None}
                property_info['Beds'] = out
            else:
                property_info['Beds'] = out
        elif re.match(contacts,out):
            if property_info['Contact'] != None:
                output_final.append(property_info)
                property_info = {'Address': None, 'Price': None, 'Beds': None, 'Contact' : None}
                property_info['Contact'] = out
            else:
                property_info['Contact'] = out
    print(output_final)
    return output_final

# %%
output = get_regex_data_primary(link)
data = consolidate(output)
df = pd.DataFrame(data)
print(df)
# Out:
# [{'Address': '1350 N Lake Shore Dr Chicago', 'Price': '$1,272 - $2,994', 'Beds': 'Studio - 2 Br', 'Contact': '312-462-0403'}, {'Address': '1212 W Madison St Chicago', 'Price': '$1,875 - $3,250', 'Beds': 'Studio - 2 Br', 'Contact': '844-737-7559'}, {'Address': '1 W Superior St Chicago', 'Price': '$1,636 - $4,673', 'Beds': 'Studio - 2 Br', 'Contact': '312-219-9516'}, {'Address': '37 W Van Buren St Chicago', 'Price': None, 'Beds': 'Studio - 4 Br', 'Contact': '844-250-5735'}, {'Address': '910 W Huron St Chicago', 'Price': '$1,925 - $3,410', 'Beds': 'Studio - 4 Br', 'Contact': '844-741-2982'}, {'Address': '707 N Wells St Chicago', 'Price': '$2,740 - $5,621', 'Beds': '1-3 Br', 'Contact': '844-837-3913'}, {'Address': '730 W Couch Pl Chicago', 'Price': '$1,750 - $5,250', 'Beds': 'Studio - 3 Br', 'Contact': '844-294-8524'}, {'Address': '1225 N Wells St Chicago', 'Price': '$1,105 - $2,530', 'Beds': 'Studio - 3 Br', 'Contact': '844-406-5855'}, {'Address': '365 N Halsted St Chicago', 'Price': '$1,645 - $4,147', 'Beds': 'Studio - 3 Br', 'Contact': '844-841-6325'}, {'Address': '625 W Division St Chicago', 'Price': '$1,687 - $6,683', 'Beds': 'Studio - 3 Br', 'Contact': '844-368-4250'}, {'Address': '343 W Wolf Point Plz Chicago', 'Price': '$1,775 - $3,700', 'Beds': 'Studio - 2 Br', 'Contact': '844-525-6919'}, {'Address': '14 W Elm St Chicago', 'Price': '$1,741 - $10,617', 'Beds': 'Studio - 3 Br', 'Contact': '844-811-0188'}, {'Address': '355 E Ohio St Chicago', 'Price': '$1,883 - $7,000', 'Beds': 'Studio - 3 Br', 'Contact': '773-675-1758'}, {'Address': '180 N Jefferson St Chicago', 'Price': '$1,600 - $4,120', 'Beds': 'Studio - 3 Br', 'Contact': '312-646-4953'}, {'Address': '448 E Ontario St Chicago', 'Price': '$1,450 - $4,015', 'Beds': 'Studio - 2 Br', 'Contact': '866-661-2651'}, {'Address': '188 W Randolph St Chicago', 'Price': '$1,500 - $5,620', 'Beds': 'Studio - 2 Br', 'Contact': '773-570-3150'}, {'Address': '111 W Wacker Dr Chicago', 'Price': '$1,697 - $9,033', 'Beds': 'Studio - 3 Br', 'Contact': '877-331-6062'}, {'Address': '150 W Roosevelt Rd Chicago', 'Price': '$1,935 - $3,534', 'Beds': '1-2 Br', 'Contact': '708-546-4173'}, {'Address': '73 E Lake St Chicago', 'Price': '$2,130 - $3,585', 'Beds': 'Studio - 2 Br', 'Contact': '312-789-5353'}, {'Address': '215 E Chestnut St Chicago', 'Price': '$1,625 - $2,980', 'Beds': '1-2 Br', 'Contact': '844-233-2845'}, {'Address': '420 E Ohio St Chicago', 'Price': '$1,585 - $4,065', 'Beds': 'Studio - 3 Br', 'Contact': '888-449-2602'}, {'Address': '922 W Washington Blvd Chicago  C', 'Price': None, 'Beds': None, 'Contact': '888-380-0393'}, {'Address': '900 S Clark St Chicago', 'Price': '$1,711 - $3,351', 'Beds': '1-3 Br', 'Contact': '773-358-4744'}, {'Address': '2555 N Clark St Chicago', 'Price': '$1,493 - $2,228', 'Beds': 'Studio - 2 Br', 'Contact': '877-834-2986'}]
#                              Address             Price           Beds  \
# 0       1350 N Lake Shore Dr Chicago   $1,272 - $2,994  Studio - 2 Br
# 1          1212 W Madison St Chicago   $1,875 - $3,250  Studio - 2 Br
# 2            1 W Superior St Chicago   $1,636 - $4,673  Studio - 2 Br
# 3          37 W Van Buren St Chicago              None  Studio - 4 Br
# 4             910 W Huron St Chicago   $1,925 - $3,410  Studio - 4 Br
# 5             707 N Wells St Chicago   $2,740 - $5,621         1-3 Br
# 6             730 W Couch Pl Chicago   $1,750 - $5,250  Studio - 3 Br
# 7            1225 N Wells St Chicago   $1,105 - $2,530  Studio - 3 Br
# 8           365 N Halsted St Chicago   $1,645 - $4,147  Studio - 3 Br
# 9          625 W Division St Chicago   $1,687 - $6,683  Studio - 3 Br
# 10      343 W Wolf Point Plz Chicago   $1,775 - $3,700  Studio - 2 Br
# 11               14 W Elm St Chicago  $1,741 - $10,617  Studio - 3 Br
# 12             355 E Ohio St Chicago   $1,883 - $7,000  Studio - 3 Br
# 13        180 N Jefferson St Chicago   $1,600 - $4,120  Studio - 3 Br
# 14          448 E Ontario St Chicago   $1,450 - $4,015  Studio - 2 Br
# 15         188 W Randolph St Chicago   $1,500 - $5,620  Studio - 2 Br
# 16           111 W Wacker Dr Chicago   $1,697 - $9,033  Studio - 3 Br
# 17        150 W Roosevelt Rd Chicago   $1,935 - $3,534         1-2 Br
# 18              73 E Lake St Chicago   $2,130 - $3,585  Studio - 2 Br
# 19         215 E Chestnut St Chicago   $1,625 - $2,980         1-2 Br
# 20             420 E Ohio St Chicago   $1,585 - $4,065  Studio - 3 Br
# 21  922 W Washington Blvd Chicago  C              None           None
# 22            900 S Clark St Chicago   $1,711 - $3,351         1-3 Br
# 23           2555 N Clark St Chicago   $1,493 - $2,228  Studio - 2 Br
#
#          Contact
# 0   312-462-0403
# 1   844-737-7559
# 2   312-219-9516
# 3   844-250-5735
# 4   844-741-2982
# 5   844-837-3913
# 6   844-294-8524
# 7   844-406-5855
# 8   844-841-6325
# 9   844-368-4250
# 10  844-525-6919
# 11  844-811-0188
# 12  773-675-1758
# 13  312-646-4953
# 14  866-661-2651
# 15  773-570-3150
# 16  877-331-6062
# 17  708-546-4173
# 18  312-789-5353
# 19  844-233-2845
# 20  888-449-2602
# 21  888-380-0393
# 22  773-358-4744
# 23  877-834-2986
